# %%
import pandas as pd

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

display(file1.head())
display(file2.head())
display(file3.head())

# print(file1.dtypes)
# print(file2.dtypes)
# print(file3.dtypes)
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file1.shape
# file2.shape
# file3.shape
# Out:
# (4008, 11)

# %%
print(file1.dtypes)
# print(file2.dtypes)
# print(file3.dtypes)  
# show the numerical column and the numerical column in the 3 files
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
col1 = []
for column in file1.columns:
    col1.append(column.lower())
col1
file1.columns = col1
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
col2 = []
for column in file2.columns:
    col2.append(column.lower())
col2
file2.columns = col2
file2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
col3 = []
for column in file3.columns:
    col3.append(column.lower())
col3
file3.columns = col3
file3
file3.shape
# Out:
# (7070, 11)

# %%
file3.rename(columns={"state": "st"}, inplace=True)

file3
# Out:
#      customer          st  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
file2 = file2[[ "st", "gender", "education", "customer lifetime value",  "income", "monthly premium auto", "number of open complaints", "policy type", "vehicle class", "total claim amount" ]]

file2
# Out:
#              st gender education customer lifetime value  income  \
# 0       Arizona      F  Bachelor              323912.47%   16061
# 1    California      F    Master              462680.11%   79487
# 2    California      F   College              899704.02%   54230
# 3        Oregon      F   College             2580706.30%   71210
# 4       Arizona      F   College              380812.21%   94903
# ..          ...    ...       ...                     ...     ...
# 991     Arizona      M    Master              847141.75%   63513
# 992     Arizona      F   College              543121.91%   58161
# 993      Nevada      F   College              568964.41%   83640
# 994  California      F    Master              368672.38%       0
# 995  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# 0                      88                    1/0/00   Personal Auto
# ...

# %%
file3 = file3[[ "st", "gender", "education", "customer lifetime value",  "income", "monthly premium auto", "number of open complaints", "policy type", "vehicle class", "total claim amount" ]]

file3
# Out:
#               st gender             education  customer lifetime value  \
# 0     Washington      M  High School or Below              3479.137523
# 1        Arizona      M                Master              2502.637401
# 2         Nevada      F              Bachelor              3265.156348
# 3     California      F  High School or Below              4455.843406
# 4     California      M  High School or Below              7704.958480
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#       income  monthly premium auto  number of open complaints     policy type  \
# ...

# %%
file1
# file2
# file3
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2
# Out:
#              st gender education customer lifetime value  income  \
# 0       Arizona      F  Bachelor              323912.47%   16061
# 1    California      F    Master              462680.11%   79487
# 2    California      F   College              899704.02%   54230
# 3        Oregon      F   College             2580706.30%   71210
# 4       Arizona      F   College              380812.21%   94903
# ..          ...    ...       ...                     ...     ...
# 991     Arizona      M    Master              847141.75%   63513
# 992     Arizona      F   College              543121.91%   58161
# 993      Nevada      F   College              568964.41%   83640
# 994  California      F    Master              368672.38%       0
# 995  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# 0                      88                    1/0/00   Personal Auto
# ...

# %%
file3
# Out:
#               st gender             education  customer lifetime value  \
# 0     Washington      M  High School or Below              3479.137523
# 1        Arizona      M                Master              2502.637401
# 2         Nevada      F              Bachelor              3265.156348
# 3     California      F  High School or Below              4455.843406
# 4     California      M  High School or Below              7704.958480
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#       income  monthly premium auto  number of open complaints     policy type  \
# ...

# %%
file11 = file1["customer lifetime value"].copy()
print(file11)
# Out:
# 0               NaN
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 4003            NaN
# 4004            NaN
# 4005            NaN
# 4006            NaN
# 4007            NaN
# Name: customer lifetime value, Length: 4008, dtype: object

# %%
file1['customer lifetime value'] = file1['customer lifetime value'].str.rstrip('%').astype('float') / 100.0

display(file1)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# ...

# %%
file2['customer lifetime value'] = file2['customer lifetime value'].str.rstrip('%').astype('float') / 100.0

display(file2)
# Out:
# C:\Users\Emmanuel\AppData\Local\Temp\ipykernel_25848\304676683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file2['customer lifetime value'] = file2['customer lifetime value'].str.rstrip('%').astype('float') / 100.0
#              st gender education  customer lifetime value  income  \
# 0       Arizona      F  Bachelor                3239.1247   16061
# 1    California      F    Master                4626.8011   79487
# 2    California      F   College                8997.0402   54230
# 3        Oregon      F   College               25807.0630   71210
# 4       Arizona      F   College                3808.1221   94903
# ..          ...    ...       ...                      ...     ...
# ...

# %%
data1 = pd.concat([file1, file2, file3], axis=0) 

display(data1.head(60))
data1.shape
# Out:
#    customer          st gender             education  customer lifetime value  \
# 0   RB50392  Washington    NaN                Master                      NaN
# 1   QZ44356     Arizona      F              Bachelor                6979.5359
# 2   AI49188      Nevada      F              Bachelor               12887.4317
# 3   WW63253  California      M              Bachelor                7645.8618
# 4   GA49547  Washington      M  High School or Below                5363.0765
# 5   OC83172      Oregon      F              Bachelor                8256.2978
# 6   XZ87318      Oregon      F               College                5380.8986
# 7   CF85061     Arizona      M                Master                7216.1003
# 8   DY87989      Oregon      M              Bachelor               24127.5040
# 9   BQ94931      Oregon      F               College                7388.1781
# 10  SX51350  California      M               College                4738.9920
# ...

# %%
data1.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count              9130.000000   9137.000000           9137.000000
# mean               7977.057704  37828.820291            110.391266
# std                6809.350707  30358.716159            581.376032
# min                1898.007675      0.000000             61.000000
# 25%                3980.525782      0.000000             68.000000
# 50%                5764.716400  34244.000000             83.000000
# 75%                8931.773240  62447.000000            109.000000
# max               83325.381190  99981.000000          35354.000000
#
#        total claim amount
# count         9137.000000
# mean           430.527140
# std            289.582968
# min              0.099007
# 25%            266.996814
# 50%            377.561463
# 75%            546.420009
# max           2893.239678

# %%
data2= data1.drop(["education", "number of open complaints" ], axis=1)
data2
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F              6979.535900      0.0
# 2     AI49188      Nevada      F             12887.431700  48767.0
# 3     WW63253  California      M              7645.861800      0.0
# 4     GA49547  Washington      M              5363.076500  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065      NaN  California      M             23405.987980  71941.0
# 7066      NaN  California      F              3096.511217  21604.0
# 7067      NaN  California      M              8163.890428      0.0
# 7068      NaN  California      M              7524.442436  21941.0
# 7069      NaN  California      M              2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN  California      M              Bachelor
# 7066      NaN  California      F               College
# 7067      NaN  California      M              Bachelor
# 7068      NaN  California      M               College
# 7069      NaN  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                 6979.535900      0.0                  94.0
# 2                12887.431700  48767.0                 108.0
# ...

# %%
data2['st'].unique()
# data2['customer'].unique()
# data2['gender'].unique()
# data2['income'].unique()
# data2['monthly premium auto'].unique()
# data2['policy type'].unique()
# data2['vehicule class'].unique()
# data2['total claim amount'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
data2.dtypes
# Out:
# customer                    object
# st                          object
# gender                      object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
data2["customer lifetime value"].dtypes
# Out:
# dtype('float64')

# %%
data2.isna().sum()
# Out:
# customer                   11003
# st                          2937
# gender                      3059
# customer lifetime value     2944
# income                      2937
# monthly premium auto        2937
# policy type                 2937
# vehicle class               2937
# total claim amount          2937
# dtype: int64

# %%
round(data2.isna().sum()/len(data2),4)*100  # shows the percentage of null values in a column
nulls_df = pd.DataFrame(round(data2.isna().sum()/len(data2),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                header_name  percent_nulls
# 0                 customer          91.13
# 1                       st          24.32
# 2                   gender          25.34
# 3  customer lifetime value          24.38
# 4                   income          24.32
# 5     monthly premium auto          24.32
# 6              policy type          24.32
# 7            vehicle class          24.32
# 8       total claim amount          24.32

# %%
data3= data2.drop_duplicates()
display(data3)
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F              6979.535900      0.0
# 2     AI49188      Nevada      F             12887.431700  48767.0
# 3     WW63253  California      M              7645.861800      0.0
# 4     GA49547  Washington      M              5363.076500  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065      NaN  California      M             23405.987980  71941.0
# 7066      NaN  California      F              3096.511217  21604.0
# 7067      NaN  California      M              8163.890428      0.0
# 7068      NaN  California      M              7524.442436  21941.0
# 7069      NaN  California      M              2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data4 = data2.drop_duplicates(keep="first")
display(data4)
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F              6979.535900      0.0
# 2     AI49188      Nevada      F             12887.431700  48767.0
# 3     WW63253  California      M              7645.861800      0.0
# 4     GA49547  Washington      M              5363.076500  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065      NaN  California      M             23405.987980  71941.0
# 7066      NaN  California      F              3096.511217  21604.0
# 7067      NaN  California      M              8163.890428      0.0
# 7068      NaN  California      M              7524.442436  21941.0
# 7069      NaN  California      M              2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
filtered_data= data3[data3['income']>0]
display(filtered_data.tail(60))
filtered_data.shape
# Out:
#      customer          st gender  customer lifetime value   income  \
# 6977      NaN  California      M             11073.105720  82807.0
# 6978      NaN  California      F              2499.469914  72021.0
# 6979      NaN  California      M              5386.512585  41228.0
# 6980      NaN  California      F              6656.200678  39834.0
# 6981      NaN  California      M              2702.692335  22415.0
# 6982      NaN  California      F              2567.346739  61900.0
# 6983      NaN  California      F              2776.748342  30893.0
# 6984      NaN  California      F              9065.259260  40006.0
# 6985      NaN  California      F             32104.699570  89546.0
# 6987      NaN  California      M              2982.196702  79523.0
# 6988      NaN  California      M              2736.352663  17533.0
# 6989      NaN  California      M              8996.774075  49706.0
# 6990      NaN  California      M              5850.451386  24317.0
# ...
